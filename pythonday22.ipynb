# %% [markdown]
# <a href="https://colab.research.google.com/github/gfeyzakorkmaz/gfeyzakorkmaz/blob/main/pythonday22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/drive/MyDrive/Dataset/marketing_analysis_data.xlsx'

# %%
df = pd.read_excel(path)
data = df.to_dict()

# %%
df = pd.DataFrame(data)

campaigns = df['Campaign'].unique()

for campaign in campaigns:
    subset = df[df['Campaign'] == campaign]
    plt.plot(subset.index, subset['Ad_Spend'], label=campaign)

# %%
plt.title ('Ad Spend by Campaigns')
plt.xlabel('Observation No')
plt.ylabel('Ad Spend')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df = pd.DataFrame(data)

campaigns = df['Campaign'].unique()

for campaign in campaigns:
    subset = df[df['Campaign'] == campaign]
    plt.plot(subset.index, subset['Ad_Spend'], label=campaign)


plt.title ('Ad Spend by Campaigns')
plt.xlabel('Observation No')
plt.ylabel('Ad Spend')
plt.legend()
plt.show()

# %%
products = df['Campaign'].unique()

for product in products:
    subset = df[df['Campaign'] == campaign]
    plt.plot(subset['Ad_Spend'], subset['Leads'], label=campaign)


plt.title('Ad Spend by Campaigns')
plt.xlabel('Ad Spend')
plt.ylabel('Leads')
plt.legend()
plt.show()

# %%
df['CPL'] = df['Ad_Spend'] / df['Leads']

campaigns = df['Campaign'].unique()

for campaign in campaigns:
    subset = df[df['Campaign'] == campaign]
    plt.plot(subset.index, subset['CPL'], label=campaign)

plt.title('Cost per Lead (CPL) by Campaign')
plt.xlabel('Observation Index')
plt.ylabel('Cost per Lead (CPL)')
plt.legend()
plt.show()
