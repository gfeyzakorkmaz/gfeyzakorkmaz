# %% [markdown]
# <a href="https://colab.research.google.com/github/gfeyzakorkmaz/gfeyzakorkmaz/blob/main/pythonday57.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Dataset/complex_marketing_data_enriched.xlsx'

# %%
df = pd.read_excel(path)
df.head(20)
# Out:
#     Customer ID  Age Gender  Total Spent  Converted  \
# 0             1   23      F          150          1
# 1             2   35      M          600          1
# 2             3   45      F          800          0
# 3             4   52      M          200          0
# 4             5   29      F          300          1
# 5             6   41      M          450          0
# 6             7   38      F          670          1
# 7             8   27      M          120          1
# 8             9   50      F          500          0
# 9            10   33      M          750          1
# 10           11   40      F          610          1
# 11           12   24      M          290          0
# 12           13   48      F          400          1
# 13           14   32      M          320          0
# 14           15   36      F          510          1
# 15           16   28      M          350          1
# 16           17   42      F          550          0
# 17           18   35      M          700          1
# 18           19   50      F          250          0
# 19           20   25      F          400          1
#
#                            Comments Purchased Category  Stock Region  \
# 0        Satisfied with the service           Clothing      4   East
# 1     Needs improvement in delivery             Beauty     86   West
# 2                  Regular customer              Books     24  North
# 3                  Occasional buyer             Beauty     10   East
# 4                      High spender              Books     47   East
# 5                Average experience              Books     86   West
# 6           Prefers online shopping         Home Goods     69  North
# 7                      New customer         Home Goods      0  North
# 8                Loyal to the brand        Electronics     86   East
# 9              High conversion rate           Clothing     45  South
# 10                   Low engagement         Home Goods     68   East
# 11   Satisfied with product quality         Home Goods     38   East
# 12                 Frequent shopper             Beauty      0   East
# 13             Unhappy with returns        Electronics     85   East
# 14                 Enjoys discounts        Electronics     55   West
# 15               Enjoys the product        Electronics     13  North
# 16           Needs more information              Books     92   West
# 17  Satisfied with customer service           Clothing     87   West
# 18                   Not interested              Books     21   West
# 19                 Likes the design         Home Goods     68   East
#
#    Income Level  Discount Availed  Customer Tenure (Years)      Campaign  \
# 0        Medium                46                        4   Winter Sale
# 1           Low                61                       12   Summer Sale
# 2        Medium                50                       12  Black Friday
# 3        Medium                54                        7   Winter Sale
# 4        Medium                63                       12   Winter Sale
# 5        Medium                 2                       13           NaN
# 6           Low                50                        8   Winter Sale
# 7           Low                 6                        3   Winter Sale
# 8        Medium                20                       14   Winter Sale
# 9        Medium                72                        1           NaN
# 10          Low                38                        4   Winter Sale
# 11          Low                17                        2  Black Friday
# 12          Low                 3                        8           NaN
# 13         High                88                        4  Black Friday
# 14         High                59                        2           NaN
# 15         High                13                       14   Winter Sale
# 16       Medium                 8                        6  Black Friday
# 17         High                89                        6           NaN
# 18       Medium                52                       10   Summer Sale
# 19       Medium                 1                        4   Winter Sale
#
#     Return Rate (%)  Website Visit Frequency  Average Cart Value
# 0          2.981829                        3              378.00
# 1          1.833412                        6              315.52
# 2          6.547401                        0              250.69
# 3          3.923717                        1              222.58
# 4          2.306644                        4              298.68
# 5          3.238817                        3              158.28
# 6          2.738895                        1              290.23
# 7          5.268858                        7              181.40
# 8          6.164246                        3              296.54
# 9          6.775497                        4              237.93
# 10         6.788665                        2              220.88
# 11         6.509996                        1              183.59
# 12         4.585668                        4              223.24
# 13         3.753045                        4              291.71
# 14         1.983693                        1              328.29
# 15         7.199294                        2              289.48
# 16         4.644536                        3              352.29
# 17         4.179233                        5              440.44
# 18         7.359433                        5              225.66
# 19         3.203584                        3              234.56

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


X = df[['Age', 'Discount Availed', 'Customer Tenure (Years)']]
y = df['Total Spent']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


model = LinearRegression()
model.fit(X_train, y_train)


y_pred = model.predict(X_test)
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 Score:', r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 23295.782426848284
# R2 Score: 0.2528746838605449

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt

df['Sentiment'] = df['Comments'].apply(lambda x: TextBlob(x).sentiment.polarity)
print(df[['Comments', 'Sentiment']].head())


average_sentiment = df.groupby('Region')['Sentiment'].mean()
average_sentiment.plot(kind='bar', title='Average Sentiment by Region', figsize=(8, 6))
plt.ylabel('Average Sentiment')
plt.show()
# Out:
#                         Comments  Sentiment
# 0     Satisfied with the service       0.50
# 1  Needs improvement in delivery       0.00
# 2               Regular customer       0.00
# 3               Occasional buyer       0.00
# 4                   High spender       0.16

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


X = df[['Age', 'Discount Availed', 'Website Visit Frequency', 'Average Cart Value']]
y = df['Converted']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# XGBoost modeli
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb.fit(X_train, y_train)

# Tahmin ve doğruluk
y_pred = xgb.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8333333333333334
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:26:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.ensemble import RandomForestRegressor


X = df[['Customer Tenure (Years)', 'Website Visit Frequency', 'Discount Availed']]
y = df['Total Spent']


rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X, y)

# Özellik önemleri
importances = rf_model.feature_importances_
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
print(feature_importance.sort_values(by='Importance', ascending=False))
# Out:
#                    Feature  Importance
# 2         Discount Availed    0.423502
# 1  Website Visit Frequency    0.322711
# 0  Customer Tenure (Years)    0.253787

# %%
import plotly.express as px


fig = px.scatter_3d(
    df,
    x='Total Spent',
    y='Discount Availed',
    z='Average Cart Value',
    color='Region',
    title='3D Visualization of Regional Spending',
    labels={'x': 'Total Spent', 'y': 'Discount Availed', 'z': 'Average Cart Value'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a05ecd3c-d9cc-48ac-85d4-e5730dccb957" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a05ecd3c-d9cc-48ac-85d4-e5730dccb957")) {                    Plotly.newPlot(                        "a05ecd3c-d9cc-48ac-85d4-e5730dccb957",                        [{"hovertemplate":"Region=East\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eDiscount Availed=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"East","scene":"scene","showlegend":true,"x":[150,200,300,500,610,290,400,320,400],"y":[46,54,63,20,38,17,3,88,1],"z":[378.0,222.58,298.68,296.54,220.88,183.59,223.24,291.71,234.56],"type":"scatter3d"},{"hovertemplate":"Region=West\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eDiscount Availed=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"West","scene":"scene","showlegend":true,"x":[600,450,510,550,700,250],"y":[61,2,59,8,89,52],"z":[315.52,158.28,328.29,352.29,440.44,225.66],"type":"scatter3d"},{"hovertemplate":"Region=North\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eDiscount Availed=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"North","scene":"scene","showlegend":true,"x":[800,670,120,350],"y":[50,50,6,13],"z":[250.69,290.23,181.4,289.48],"type":"scatter3d"},{"hovertemplate":"Region=South\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eDiscount Availed=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"South","scene":"scene","showlegend":true,"x":[750],"y":[72],"z":[237.93],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""}," ...

# %%
import plotly.express as px

fig = px.scatter_3d(
    df,
    x='Total Spent',
    y='Customer Tenure (Years)',
    z='Average Cart Value',
    color='Region',
    title='3D Scatter Plot of Spending vs Tenure',
    labels={'x': 'Total Spent', 'y': 'Tenure', 'z': 'Cart Value'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52e18cc9-8165-4b21-91c1-1ce682b41bdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52e18cc9-8165-4b21-91c1-1ce682b41bdf")) {                    Plotly.newPlot(                        "52e18cc9-8165-4b21-91c1-1ce682b41bdf",                        [{"hovertemplate":"Region=East\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eCustomer Tenure (Years)=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"East","scene":"scene","showlegend":true,"x":[150,200,300,500,610,290,400,320,400],"y":[4,7,12,14,4,2,8,4,4],"z":[378.0,222.58,298.68,296.54,220.88,183.59,223.24,291.71,234.56],"type":"scatter3d"},{"hovertemplate":"Region=West\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eCustomer Tenure (Years)=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"West","scene":"scene","showlegend":true,"x":[600,450,510,550,700,250],"y":[12,13,2,6,6,10],"z":[315.52,158.28,328.29,352.29,440.44,225.66],"type":"scatter3d"},{"hovertemplate":"Region=North\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eCustomer Tenure (Years)=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"North","scene":"scene","showlegend":true,"x":[800,670,120,350],"y":[12,8,3,14],"z":[250.69,290.23,181.4,289.48],"type":"scatter3d"},{"hovertemplate":"Region=South\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eCustomer Tenure (Years)=%{y}\u003cbr\u003eAverage Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"South","scene":"scene","showlegend":true,"x":[750],"y":[1],"z":[237.93],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewi ...

# %%
import plotly.graph_objects as go
import numpy as np


z_data = df.pivot_table(values='Total Spent', index='Region', columns='Income Level', aggfunc='mean').fillna(0).values

fig = go.Figure(data=[go.Surface(z=z_data)])
fig.update_layout(title='3D Surface Plot of Spending by Region and Income Level')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="aa034e65-fd66-4718-82b9-dca25619a34c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa034e65-fd66-4718-82b9-dca25619a34c")) {                    Plotly.newPlot(                        "aa034e65-fd66-4718-82b9-dca25619a34c",                        [{"z":[[320.0,433.3333333333333,310.0],[350.0,395.0,800.0],[0.0,0.0,750.0],[605.0,600.0,416.6666666666667]],"type":"surface"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"c ...

# %%
fig = px.line_3d(
    df,
    x='Customer Tenure (Years)',
    y='Total Spent',
    z='Discount Availed',
    color='Region',
    title='3D Line Plot of Spending Over Customer Tenure'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b259f4fe-115b-4c61-bf62-5c08afa3a4e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b259f4fe-115b-4c61-bf62-5c08afa3a4e5")) {                    Plotly.newPlot(                        "b259f4fe-115b-4c61-bf62-5c08afa3a4e5",                        [{"hovertemplate":"Region=East\u003cbr\u003eCustomer Tenure (Years)=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East","scene":"scene","showlegend":true,"x":[4,7,12,14,4,2,8,4,4],"y":[150,200,300,500,610,290,400,320,400],"z":[46,54,63,20,38,17,3,88,1],"type":"scatter3d"},{"hovertemplate":"Region=West\u003cbr\u003eCustomer Tenure (Years)=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"West","scene":"scene","showlegend":true,"x":[12,13,2,6,6,10],"y":[600,450,510,550,700,250],"z":[61,2,59,8,89,52],"type":"scatter3d"},{"hovertemplate":"Region=North\u003cbr\u003eCustomer Tenure (Years)=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North","scene":"scene","showlegend":true,"x":[12,8,3,14],"y":[800,670,120,350],"z":[50,50,6,13],"type":"scatter3d"},{"hovertemplate":"Region=South\u003cbr\u003eCustomer Tenure (Years)=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"South","scene":"scene","showlegend":true,"x":[1],"y":[750],"z":[72],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth ...

# %%
fig = px.scatter_3d(
    df,
    x='Age',
    y='Total Spent',
    z='Discount Availed',
    size='Average Cart Value',
    color='Region',
    title='3D Bubble Chart of Spending by Age and Discounts'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1ed2f01f-67ad-4e3e-909f-33be4eb54a4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ed2f01f-67ad-4e3e-909f-33be4eb54a4f")) {                    Plotly.newPlot(                        "1ed2f01f-67ad-4e3e-909f-33be4eb54a4f",                        [{"hovertemplate":"Region=East\u003cbr\u003eAge=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cbr\u003eAverage Cart Value=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#636efa","size":[378.0,222.58,298.68,296.54,220.88,183.59,223.24,291.71,234.56],"sizemode":"area","sizeref":1.1011,"symbol":"circle"},"mode":"markers","name":"East","scene":"scene","showlegend":true,"x":[23,52,29,50,40,24,48,32,25],"y":[150,200,300,500,610,290,400,320,400],"z":[46,54,63,20,38,17,3,88,1],"type":"scatter3d"},{"hovertemplate":"Region=West\u003cbr\u003eAge=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cbr\u003eAverage Cart Value=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#EF553B","size":[315.52,158.28,328.29,352.29,440.44,225.66],"sizemode":"area","sizeref":1.1011,"symbol":"circle"},"mode":"markers","name":"West","scene":"scene","showlegend":true,"x":[35,41,36,42,35,50],"y":[600,450,510,550,700,250],"z":[61,2,59,8,89,52],"type":"scatter3d"},{"hovertemplate":"Region=North\u003cbr\u003eAge=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cbr\u003eAverage Cart Value=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#00cc96","size":[250.69,290.23,181.4,289.48],"sizemode":"area","sizeref":1.1011,"symbol":"circle"},"mode":"markers","name":"North","scene":"scene","showlegend":true,"x":[45,38,27,28],"y":[800,670,120,350],"z":[50,50,6,13],"type":"scatter3d"},{"hovertemplate":"Region=South\u003cbr\u003eAge=%{x}\u003cbr\u003eTotal Spent=%{y}\u003cbr\u003eDiscount Availed=%{z}\u003cbr\u003eAverage Cart Value=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#ab63fa","size":[237.93],"sizemode":"area","sizeref":1.1011,"symbol":"circle"},"mode":"markers","name":"South","scene":"scene","showlegend":true,"x":[33],"y":[750],"z":[72],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a ...

# %%
fig = px.density_contour(
    df,
    x='Total Spent',
    y='Average Cart Value',
    z='Discount Availed',
    color='Region',
    title='3D Density Contour of Spending and Cart Value'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9fbeb1b6-a7ba-4d3f-9b29-58a3bfe2abc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fbeb1b6-a7ba-4d3f-9b29-58a3bfe2abc6")) {                    Plotly.newPlot(                        "9fbeb1b6-a7ba-4d3f-9b29-58a3bfe2abc6",                        [{"contours":{"coloring":"none"},"hovertemplate":"Region=East\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eAverage Cart Value=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","line":{"color":"#636efa"},"name":"East","showlegend":true,"x":[150,200,300,500,610,290,400,320,400],"xaxis":"x","xbingroup":"x","y":[378.0,222.58,298.68,296.54,220.88,183.59,223.24,291.71,234.56],"yaxis":"y","ybingroup":"y","z":[46,54,63,20,38,17,3,88,1],"type":"histogram2dcontour"},{"contours":{"coloring":"none"},"hovertemplate":"Region=West\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eAverage Cart Value=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","line":{"color":"#EF553B"},"name":"West","showlegend":true,"x":[600,450,510,550,700,250],"xaxis":"x","xbingroup":"x","y":[315.52,158.28,328.29,352.29,440.44,225.66],"yaxis":"y","ybingroup":"y","z":[61,2,59,8,89,52],"type":"histogram2dcontour"},{"contours":{"coloring":"none"},"hovertemplate":"Region=North\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eAverage Cart Value=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","line":{"color":"#00cc96"},"name":"North","showlegend":true,"x":[800,670,120,350],"xaxis":"x","xbingroup":"x","y":[250.69,290.23,181.4,289.48],"yaxis":"y","ybingroup":"y","z":[50,50,6,13],"type":"histogram2dcontour"},{"contours":{"coloring":"none"},"hovertemplate":"Region=South\u003cbr\u003eTotal Spent=%{x}\u003cbr\u003eAverage Cart Value=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","line":{"color":"#ab63fa"},"name":"South","showlegend":true,"x":[750],"xaxis":"x","xbingroup":"x","y":[237.93],"yaxis":"y","ybingroup":"y","z":[72],"type":"histogram2dcontour"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"c ...

# %%
fig = px.density_heatmap(
    df,
    x='Total Spent',
    y='Discount Availed',
    z='Average Cart Value',
    color_continuous_scale='Viridis',
    title='3D Heatmap of Spending and Discounts'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="14341c89-2e9e-4c54-96c9-904f8e2a6c15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14341c89-2e9e-4c54-96c9-904f8e2a6c15")) {                    Plotly.newPlot(                        "14341c89-2e9e-4c54-96c9-904f8e2a6c15",                        [{"coloraxis":"coloraxis","histfunc":"sum","hovertemplate":"Total Spent=%{x}\u003cbr\u003eDiscount Availed=%{y}\u003cbr\u003esum of Average Cart Value=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":[150,600,800,200,300,450,670,120,500,750,610,290,400,320,510,350,550,700,250,400],"xaxis":"x","xbingroup":"x","y":[46,61,50,54,63,2,50,6,20,72,38,17,3,88,59,13,8,89,52,1],"yaxis":"y","ybingroup":"y","z":[378.0,315.52,250.69,222.58,298.68,158.28,290.23,181.4,296.54,237.93,220.88,183.59,223.24,291.71,328.29,289.48,352.29,440.44,225.66,234.56],"type":"histogram2d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"mar ...

# %%
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Mesh3d(
    x=df['Total Spent'],
    y=df['Discount Availed'],
    z=df['Average Cart Value'],
    opacity=0.5,
    color='blue'
))

fig.update_layout(
    title='3D Histogram of Spending, Discounts, and Cart Value',
    scene=dict(
        xaxis_title='Total Spent',
        yaxis_title='Discount Availed',
        zaxis_title='Average Cart Value'
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1b90182d-31bb-4214-9eb6-026aa3cc1626" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b90182d-31bb-4214-9eb6-026aa3cc1626")) {                    Plotly.newPlot(                        "1b90182d-31bb-4214-9eb6-026aa3cc1626",                        [{"color":"blue","opacity":0.5,"x":[150,600,800,200,300,450,670,120,500,750,610,290,400,320,510,350,550,700,250,400],"y":[46,61,50,54,63,2,50,6,20,72,38,17,3,88,59,13,8,89,52,1],"z":[378.0,315.52,250.69,222.58,298.68,158.28,290.23,181.4,296.54,237.93,220.88,183.59,223.24,291.71,328.29,289.48,352.29,440.44,225.66,234.56],"type":"mesh3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scat ...

# %%
import numpy as np


x = df['Income Level'].astype(str)
y = df['Total Spent']
z = df['Discount Availed']

fig = go.Figure()

fig.add_trace(go.Scatter3d(
    x=x, y=y, z=z,
    mode='markers',
    marker=dict(size=5, color=y, colorscale='Viridis', opacity=0.8)
))

fig.update_layout(
    title='3D Scatter as Violin Representation',
    scene=dict(
        xaxis_title='Income Level',
        yaxis_title='Total Spent',
        zaxis_title='Discount Availed'
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25696d96-e91b-4c5a-b0d6-e0f0e42173ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25696d96-e91b-4c5a-b0d6-e0f0e42173ff")) {                    Plotly.newPlot(                        "25696d96-e91b-4c5a-b0d6-e0f0e42173ff",                        [{"marker":{"color":[150,600,800,200,300,450,670,120,500,750,610,290,400,320,510,350,550,700,250,400],"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.8,"size":5},"mode":"markers","x":["Medium","Low","Medium","Medium","Medium","Medium","Low","Low","Medium","Medium","Low","Low","Low","High","High","High","Medium","High","Medium","Medium"],"y":[150,600,800,200,300,450,670,120,500,750,610,290,400,320,510,350,550,700,250,400],"z":[46,61,50,54,63,2,50,6,20,72,38,17,3,88,59,13,8,89,52,1],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidt ...

# %%
fig = go.Figure()

for region in df['Region'].unique():
    region_data = df[df['Region'] == region]
    fig.add_trace(go.Scatter3d(
        x=[region] * len(region_data),
        y=region_data['Average Cart Value'],
        z=region_data['Discount Availed'],
        mode='markers',
        name=region
    ))

fig.update_layout(
    title='3D Box Plot of Cart Value by Region',
    scene=dict(
        xaxis_title='Region',
        yaxis_title='Average Cart Value',
        zaxis_title='Discount Availed'
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="408b626e-a11e-47f0-ae62-320e909ddc69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("408b626e-a11e-47f0-ae62-320e909ddc69")) {                    Plotly.newPlot(                        "408b626e-a11e-47f0-ae62-320e909ddc69",                        [{"mode":"markers","name":"East","x":["East","East","East","East","East","East","East","East","East"],"y":[378.0,222.58,298.68,296.54,220.88,183.59,223.24,291.71,234.56],"z":[46,54,63,20,38,17,3,88,1],"type":"scatter3d"},{"mode":"markers","name":"West","x":["West","West","West","West","West","West"],"y":[315.52,158.28,328.29,352.29,440.44,225.66],"z":[61,2,59,8,89,52],"type":"scatter3d"},{"mode":"markers","name":"North","x":["North","North","North","North"],"y":[250.69,290.23,181.4,289.48],"z":[50,50,6,13],"type":"scatter3d"},{"mode":"markers","name":"South","x":["South"],"y":[237.93],"z":[72],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color": ...

# %%
import plotly.graph_objects as go


fig = go.Figure()


for region in df['Region'].unique():
    region_data = df[df['Region'] == region]
    fig.add_trace(go.Scatter3d(
        x=region_data['Income Level'],
        y=[region] * len(region_data),
        z=region_data['Total Spent'],
        mode='markers+lines',
        marker=dict(size=10, opacity=0.8),
        name=region
    ))


fig.update_layout(
    title='3D Bar Chart of Spending by Region and Income Level',
    scene=dict(
        xaxis_title='Income Level',
        yaxis_title='Region',
        zaxis_title='Total Spent'
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="47183ea5-b52c-477d-85f9-9d5ead5e429d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47183ea5-b52c-477d-85f9-9d5ead5e429d")) {                    Plotly.newPlot(                        "47183ea5-b52c-477d-85f9-9d5ead5e429d",                        [{"marker":{"opacity":0.8,"size":10},"mode":"markers+lines","name":"East","x":["Medium","Medium","Medium","Medium","Low","Low","Low","High","Medium"],"y":["East","East","East","East","East","East","East","East","East"],"z":[150,200,300,500,610,290,400,320,400],"type":"scatter3d"},{"marker":{"opacity":0.8,"size":10},"mode":"markers+lines","name":"West","x":["Low","Medium","High","Medium","High","Medium"],"y":["West","West","West","West","West","West"],"z":[600,450,510,550,700,250],"type":"scatter3d"},{"marker":{"opacity":0.8,"size":10},"mode":"markers+lines","name":"North","x":["Medium","Low","Low","High"],"y":["North","North","North","North"],"z":[800,670,120,350],"type":"scatter3d"},{"marker":{"opacity":0.8,"size":10},"mode":"markers+lines","name":"South","x":["Medium"],"y":["South"],"z":[750],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"par ...
