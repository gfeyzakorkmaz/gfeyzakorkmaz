# %% [markdown]
# <a href="https://colab.research.google.com/github/gfeyzakorkmaz/gfeyzakorkmaz/blob/main/pythonday50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Dataset/extended_marketing_data_new.xlsx'

# %%
df = pd.read_excel(path)
df.head(20)
# Out:
#     Customer ID  Age Gender  Total Spent  Converted  \
# 0             1   23      F          150          1
# 1             2   35      M          600          1
# 2             3   45      F          800          0
# 3             4   52      M          200          0
# 4             5   29      F          300          1
# 5             6   41      M          450          0
# 6             7   38      F          670          1
# 7             8   27      M          120          1
# 8             9   50      F          500          0
# 9            10   33      M          750          1
# 10           11   40      F          610          1
# 11           12   24      M          290          0
# 12           13   48      F          400          1
# 13           14   32      M          320          0
# 14           15   36      F          510          1
# 15           16   28      M          350          1
# 16           17   42      F          550          0
# 17           18   35      M          700          1
# 18           19   50      F          250          0
# 19           20   25      F          400          1
#
#                            Comments Purchased Category  Stock
# 0        Satisfied with the service           Clothing      4
# 1     Needs improvement in delivery             Beauty     86
# 2                  Regular customer              Books     24
# 3                  Occasional buyer             Beauty     10
# 4                      High spender              Books     47
# 5                Average experience              Books     86
# 6           Prefers online shopping         Home Goods     69
# 7                      New customer         Home Goods      0
# 8                Loyal to the brand        Electronics     86
# 9              High conversion rate           Clothing     45
# 10                   Low engagement         Home Goods     68
# 11   Satisfied with product quality         Home Goods     38
# 12                 Frequent shopper             Beauty      0
# 13             Unhappy with returns        Electronics     85
# 14                 Enjoys discounts        Electronics     55
# 15               Enjoys the product        Electronics     13
# 16           Needs more information              Books     92
# 17  Satisfied with customer service           Clothing     87
# 18                   Not interested              Books     21
# 19                 Likes the design         Home Goods     68

# %% [markdown]
# CPA

# %%
df['Total Cost'] = df['Total Spent']
df['Profitability'] = df['Total Cost'] - df['Stock']

df['Profitability (%)'] = (df['Profitability'] / df['Stock']) * 100

print(df)

df.plot(x='Customer ID', y='Profitability', kind='bar', title='Customer Profitability Analysis')
# Out:
#     Customer ID  Age Gender  Total Spent  Converted  \
# 0             1   23      F          150          1
# 1             2   35      M          600          1
# 2             3   45      F          800          0
# 3             4   52      M          200          0
# 4             5   29      F          300          1
# 5             6   41      M          450          0
# 6             7   38      F          670          1
# 7             8   27      M          120          1
# 8             9   50      F          500          0
# 9            10   33      M          750          1
# 10           11   40      F          610          1
# 11           12   24      M          290          0
# 12           13   48      F          400          1
# 13           14   32      M          320          0
# 14           15   36      F          510          1
# 15           16   28      M          350          1
# 16           17   42      F          550          0
# 17           18   35      M          700          1
# 18           19   50      F          250          0
# 19           20   25      F          400          1
#
#                            Comments Purchased Category  Stock  Total Cost  \
# 0        Satisfied with the service           Clothing      4         150
# 1     Needs improvement in delivery             Beauty     86         600
# 2                  Regular customer              Books     24         800
# 3                  Occasional buyer             Beauty     10         200
# 4                      High spender              Books     47         300
# 5                Average experience              Books     86         450
# 6           Prefers online shopping         Home Goods     69         670
# 7                      New customer         Home Goods      0         120
# 8                Loyal to the brand        Electronics     86         500
# 9              High conversion rate           Clothing     45         750
# 10                   Low engagement         Home Goods     68         610
# 11   Satisfied with product quality         Home Goods     38         290
# 12                 Frequent shopper             Beauty      0         400
# 13             Unhappy with returns        Electronics     85         320
# 14                 Enjoys discounts        Electronics     55         510
# 15               Enjoys the product        Electronics     13         350
# 16           Needs more information              Books     92         550
# 17  Satisfied with customer service           Clothing     87         700
# 18                   Not interested              Books     21         250
# 19                 Likes the design         Home Goods     68         400
#
#     Profitability  Profitability (%)
# 0             146        3650.000000
# 1             514         597.674419
# 2             776        3233.333333
# 3             190        1900.000000
# 4             253         538.297872
# 5             364         423.255814
# 6             601         871.014493
# 7             120                inf
# 8             414         481.395349
# 9             705        1566.666667
# 10            542         797.058824
# 11            252         663.157895
# 12            400                inf
# 13            235         276.470588
# 14            455         827.272727
# 15            337        2592.307692
# 16            458         497.826087
# 17            613         704.597701
# 18            229        1090.476190
# 19            332         488.235294
# <Axes: title={'center': 'Customer Profitability Analysis'}, xlabel='Customer ID'>

# %% [markdown]
# ABC

# %%
import pandas as pd

activity_data = {
    'Activity'
    'Total Spent'
    'Gender'
    'Purchased Category'
    'Stock'

}
activity_df = pd.read_excel(path)


activity_df['Stock'] = pd.to_numeric(activity_df['Stock'], errors='coerce')

activity_df['Cost per Stock'] = activity_df['Total Spent'] / activity_df['Stock']

customer_df = pd.read_excel(path)

print(customer_df)

customer_df.plot(x='Customer ID', y=['Total Spent', 'Purchased Category', 'Stock'])
# Out:
#     Customer ID  Age Gender  Total Spent  Converted  \
# 0             1   23      F          150          1
# 1             2   35      M          600          1
# 2             3   45      F          800          0
# 3             4   52      M          200          0
# 4             5   29      F          300          1
# 5             6   41      M          450          0
# 6             7   38      F          670          1
# 7             8   27      M          120          1
# 8             9   50      F          500          0
# 9            10   33      M          750          1
# 10           11   40      F          610          1
# 11           12   24      M          290          0
# 12           13   48      F          400          1
# 13           14   32      M          320          0
# 14           15   36      F          510          1
# 15           16   28      M          350          1
# 16           17   42      F          550          0
# 17           18   35      M          700          1
# 18           19   50      F          250          0
# 19           20   25      F          400          1
#
#                            Comments Purchased Category  Stock
# 0        Satisfied with the service           Clothing      4
# 1     Needs improvement in delivery             Beauty     86
# 2                  Regular customer              Books     24
# 3                  Occasional buyer             Beauty     10
# 4                      High spender              Books     47
# 5                Average experience              Books     86
# 6           Prefers online shopping         Home Goods     69
# 7                      New customer         Home Goods      0
# 8                Loyal to the brand        Electronics     86
# 9              High conversion rate           Clothing     45
# 10                   Low engagement         Home Goods     68
# 11   Satisfied with product quality         Home Goods     38
# 12                 Frequent shopper             Beauty      0
# 13             Unhappy with returns        Electronics     85
# 14                 Enjoys discounts        Electronics     55
# 15               Enjoys the product        Electronics     13
# 16           Needs more information              Books     92
# 17  Satisfied with customer service           Clothing     87
# 18                   Not interested              Books     21
# 19                 Likes the design         Home Goods     68
# <Axes: xlabel='Customer ID'>

# %%
import pandas as pd

activity_data = {
    'Activity'
    'Total Spent'
    'Gender'
    'Purchased Category'
    'Stock'

}
activity_df = pd.read_excel(path)


activity_df['Stock'] = pd.to_numeric(activity_df['Stock'], errors='coerce')

activity_df['Cost per Stock'] = activity_df['Total Spent'] / activity_df['Stock']

customer_df = pd.read_excel(path)

print(customer_df)

customer_df.plot(x='Customer ID', y=['Total Spent', 'Purchased Category', 'Stock'], kind='bar', stacked=True, title='Activity-Based Costing')
# Out:
#     Customer ID  Age Gender  Total Spent  Converted  \
# 0             1   23      F          150          1
# 1             2   35      M          600          1
# 2             3   45      F          800          0
# 3             4   52      M          200          0
# 4             5   29      F          300          1
# 5             6   41      M          450          0
# 6             7   38      F          670          1
# 7             8   27      M          120          1
# 8             9   50      F          500          0
# 9            10   33      M          750          1
# 10           11   40      F          610          1
# 11           12   24      M          290          0
# 12           13   48      F          400          1
# 13           14   32      M          320          0
# 14           15   36      F          510          1
# 15           16   28      M          350          1
# 16           17   42      F          550          0
# 17           18   35      M          700          1
# 18           19   50      F          250          0
# 19           20   25      F          400          1
#
#                            Comments Purchased Category  Stock
# 0        Satisfied with the service           Clothing      4
# 1     Needs improvement in delivery             Beauty     86
# 2                  Regular customer              Books     24
# 3                  Occasional buyer             Beauty     10
# 4                      High spender              Books     47
# 5                Average experience              Books     86
# 6           Prefers online shopping         Home Goods     69
# 7                      New customer         Home Goods      0
# 8                Loyal to the brand        Electronics     86
# 9              High conversion rate           Clothing     45
# 10                   Low engagement         Home Goods     68
# 11   Satisfied with product quality         Home Goods     38
# 12                 Frequent shopper             Beauty      0
# 13             Unhappy with returns        Electronics     85
# 14                 Enjoys discounts        Electronics     55
# 15               Enjoys the product        Electronics     13
# 16           Needs more information              Books     92
# 17  Satisfied with customer service           Clothing     87
# 18                   Not interested              Books     21
# 19                 Likes the design         Home Goods     68
# <Axes: title={'center': 'Activity-Based Costing'}, xlabel='Customer ID'>

# %%
activity_data = {
    'Activity': ['Order Processing', 'Customer Support', 'Marketing Campaign'],
    'Total Cost': [10000, 5000, 8000],
    'Cost Driver': ['Number of Orders', 'Support Tickets', 'Marketing Campaigns'],
    'Driver Volume': [200, 50, 10]
}

activity_df = pd.DataFrame(activity_data)


activity_df['Cost per Driver Unit'] = activity_df['Total Cost'] / activity_df['Driver Volume']


customer_activity_data = {
    'Customer ID': [1, 2, 3, 4],
    'Number of Orders': [10, 30, 20, 40],
    'Support Tickets': [2, 5, 1, 3],
    'Marketing Campaigns': [1, 2, 1, 1]
}

customer_df = pd.DataFrame(customer_activity_data)


customer_df['Order Processing Cost'] = customer_df['Number of Orders'] * activity_df.loc[0, 'Cost per Driver Unit']
customer_df['Support Cost'] = customer_df['Support Tickets'] * activity_df.loc[1, 'Cost per Driver Unit']
customer_df['Marketing Cost'] = customer_df['Marketing Campaigns'] * activity_df.loc[2, 'Cost per Driver Unit']


customer_df['Total Allocated Cost'] = (
    customer_df['Order Processing Cost'] +
    customer_df['Support Cost'] +
    customer_df['Marketing Cost']
)


print(customer_df)


customer_df.plot(x='Customer ID', y=['Order Processing Cost', 'Support Cost', 'Marketing Cost'], kind='bar', stacked=True, title='Activity-Based Costing')
# Out:
#    Customer ID  Number of Orders  Support Tickets  Marketing Campaigns  \
# 0            1                10                2                    1
# 1            2                30                5                    2
# 2            3                20                1                    1
# 3            4                40                3                    1
#
#    Order Processing Cost  Support Cost  Marketing Cost  Total Allocated Cost
# 0                  500.0         200.0           800.0                1500.0
# 1                 1500.0         500.0          1600.0                3600.0
# 2                 1000.0         100.0           800.0                1900.0
# 3                 2000.0         300.0           800.0                3100.0
# <Axes: title={'center': 'Activity-Based Costing'}, xlabel='Customer ID'>
